# %%
import sys, math
import numpy as np
import glob, copy

from skimage import io
from skimage.segmentation import quickshift

import matplotlib.pyplot as plt
from matplotlib import colors
import pylab

sys.path.append('/home/Alex/Desktop/bristol_project/')

from treeclass import tree_classifier

bristol_image = '/home/Alex/Desktop/bristol_project/bristol_tree.png'
bristol_refs = glob.glob("/home/Alex/Desktop/bristol_project/reference_images/bristol/*.png")

america_image = '/home/Alex/Desktop/bristol_project/America.png'
america_refs = glob.glob("/home/Alex/Desktop/bristol_project/reference_images/america/*.png")

# %%
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (20.0, 20.0)

# %%
bristol_trees = tree_classifier(im_location = bristol_image, ref_locations = bristol_refs)
plt.imshow(bristol_trees.treeclass_image)
# Out:
# Detected  7600  in input image.

# %%
america_refs
# Out:
# ['/home/Alex/Desktop/bristol_project/reference_images/america/america_ref_2.png',
#  '/home/Alex/Desktop/bristol_project/reference_images/america/america_ref_1.png']

# %%
america_trees = tree_classifier(im_location = america_image, ref_locations = america_refs, threshold = 0.01)
plt.imshow(america_trees.treeclass_image)
# Out:
# Detected  3373  in input image.
